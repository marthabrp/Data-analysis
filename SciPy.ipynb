# %% [markdown]
# #Análise de Dados – SciPy
# ***

# %% [markdown]
# **1.** (3,0 pontos) Usando o método scipy.stats.norm da biblioteca SciPy, escreva um programa
# para gerar 100 números aleatórios obtidos a partir da distribuição normal padrão.

# %%
from scipy import stats
from scipy.stats import norm
r = norm.rvs(size=100)
print(r)
# Out:
# [ 1.38901291  0.60857425  0.23184438  2.10504943  0.00766531 -0.54786959
#   0.5228752  -0.22516473  1.38548072 -1.3408496  -0.21545732  0.6389553
#  -0.03740027  0.89384874  0.54749107 -1.84050468 -0.24204462 -1.03152744
#  -1.18442707 -0.60768003  0.14414846 -2.37058895 -2.16688976  0.88692219
#  -0.53722637 -1.32022869  1.79761813  0.57679054  0.5261938  -0.0197623
#   2.04896303 -1.32522086 -0.6740804  -0.26908838 -1.11089831  2.77395071
#   0.35960747  0.23116647 -0.26074836  0.96653703 -0.9202699   0.70349049
#  -0.52180144 -0.13137347  0.45930369  0.0186235  -0.08156446 -0.68841978
#  -0.74017652 -0.16177131 -0.3727882   2.41755943 -1.16514547 -1.00591348
#  -1.65778127  0.63743424 -0.37895633 -0.59106144  0.04509991 -0.10705983
#  -1.53946128 -1.63592361 -1.55178879  1.54813866 -1.43898385 -0.09744884
#  -0.87691124 -1.34308906 -0.90838442  0.41704845 -0.96466805 -0.441449
#  -0.7789583   0.42259563  0.69944357  0.55247901 -0.02339734 -0.7146817
# ...

# %% [markdown]
# **2.** (4,0 pontos) Usando o método scipy.stats.poisson da biblioteca SciPy, escreva
# um programa para plotar os valores de uma distribuição Poisson com média 0.1.

# %%
from scipy.stats import poisson
import matplotlib.pyplot as plt
'''
fig, ax = plt.subplots(1, 1)
mu = 0.1
x = np.arange(poisson.ppf(0.01, mu), poisson.ppf(0.99, mu))
ax.plot(x, poisson.pmf(x, mu), 'bo', ms=8, label='poisson pmf')
ax.vlines(x, 0, poisson.pmf(x, mu), colors='b', lw=5, alpha=0.5)
#print (poisson.rvs(mu = 0.1, size=10))
#data_poisson = poisson.rvs(mu=3, size=50)
'''

# %%
from scipy.stats import poisson
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1)
mu = 0.1
mean, var, skew, kurt = poisson.stats(mu, moments='mvsk')

x = np.arange(poisson.ppf(0.01, mu), poisson.ppf(0.99, mu))

ax.plot(x, poisson.pmf(x, mu), 'bo', ms=8, label='poisson pmf')
ax.vlines(x, 0, poisson.pmf(x, mu), colors='b', lw=5, alpha=0.5)

rv = poisson(mu)

ax.vlines(x, 0, rv.pmf(x), colors='k', linestyles='-', lw=1, label='frozen pmf')
ax.legend(loc='best', frameon=False)

plt.show()

# %% [markdown]
# **3.** (4,0 pontos) Usando o método scipy.stats.expon da biblioteca SciPy, escreva um programa
# para plotar os valores de uma distribuição exponencial com média 2.

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn') # pretty matplotlib plots
plt.rcParams['figure.figsize'] = (12, 8)
import scipy.stats as ss
import numpy as np

def plot_exponential(x_range, mu=2, sigma=1, **kwargs):
    x = x_range
    y = ss.expon.pdf(x, mu, sigma)
    plt.plot(x, y, **kwargs)
x = np.linspace(0, 5, 5000)

plot_exponential(x, 0, 1, color='red', lw=2, ls='-', alpha=0.5, label='pdf')
plt.legend();
